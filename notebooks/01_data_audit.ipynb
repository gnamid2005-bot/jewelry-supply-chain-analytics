# %% [markdown]
# # 01 Data Audit
#
# Starter notebook for auditing anonymized public sample data. Do not load raw company Excel files in this notebook.

# %% [markdown]
# ## Load Sample Data
#
# This notebook expects `data/sample/anonymized_supply_chain_sample.csv` to be generated by `python -m src.anonymize`.

# %%
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sample_path = PROJECT_ROOT / "data" / "sample" / "anonymized_supply_chain_sample.csv"

df = pd.read_csv(sample_path, parse_dates=["year_month"])
df.head()

# %% [markdown]
# ## Basic Shape

# %%
row_count, column_count = df.shape
{
    "row_count": row_count,
    "column_count": column_count,
}

# %% [markdown]
# ## Field Types

# %%
df.dtypes

# %% [markdown]
# ## Missing Values

# %%
df.isna().sum().sort_values(ascending=False)

# %% [markdown]
# ## Time Range

# %%
{
    "min_year_month": df["year_month"].min(),
    "max_year_month": df["year_month"].max(),
}

# %% [markdown]
# ## Entity Counts

# %%
{
    "factory_count": df["factory"].nunique(dropna=True),
    "sku_count": df["sku_id"].nunique(dropna=True),
    "product_series_count": df["product_series"].nunique(dropna=True),
}
